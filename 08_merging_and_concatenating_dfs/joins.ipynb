# %%
import pandas as pd

# %%
df_movies = pd.read_csv("IMDb movies.csv", low_memory=False)
df_ratings = pd.read_csv("IMDb ratings.csv")

# %%
# select columns

df_movies = df_movies[['imdb_title_id', 'title', 'year', 'genre', 'country']]
df_ratings = df_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %% [markdown]
# ### 1. merge()

# %%
df1 = pd.DataFrame({
    'id': ['A','B','C','D'],
    'age': [30, 23, 25, 22]
})
df2 = pd.DataFrame({
    'id': ['C','D','E','F'],
    'job': ['Doctor', 'Statistician', 'Accountant', 'Developer']
})

# %% [markdown]
# ### 1.1 Inner Join

# %%
df_inner_join = df1.merge(df2, on='id', how='inner')
df_inner_join
# Out:
#   id  age           job
# 0  C   25        Doctor
# 1  D   22  Statistician

# %%
#shape
print(df1.shape)
print(df2.shape)
print(df_inner_join.shape)
# Out:
# (4, 2)
# (4, 2)
# (2, 3)

# %% [markdown]
# ### 1.1.1 Exercise

# %%
# merge the df_movies and df_ratings dataframes (inner join)

# %%
df_movies
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
# [85855 rows x 5 columns]

# %%
df_ratings
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0         tt0000009          154        5.9
# 1         tt0000574          589        6.3
# 2         tt0001892          188        6.0
# 3         tt0002101          446        5.3
# 4         tt0002130         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='inner')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# 2                          Drama  Germany, Denmark          188        6.0
# 3                 Drama, History               USA          446        5.3
# 4      Adventure, Drama, Fantasy             Italy         2237        6.9
# ...                          ...               ...          ...        ...
# 85850                     Comedy   France, Belgium          398        5.5
# 85851              Comedy, Drama       Netherlands          724        7.9
# 85852                      Drama             India          265        7.8
# 85853              Drama, Family            Turkey          194        9.4
# 85854                      Drama             Spain          102        6.8
#
# [85855 rows x 7 columns]

# %%
pd.merge(df_movies, df_ratings, on='imdb_title_id') # works the same as the previous code section
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# 2                          Drama  Germany, Denmark          188        6.0
# 3                 Drama, History               USA          446        5.3
# 4      Adventure, Drama, Fantasy             Italy         2237        6.9
# ...                          ...               ...          ...        ...
# 85850                     Comedy   France, Belgium          398        5.5
# 85851              Comedy, Drama       Netherlands          724        7.9
# 85852                      Drama             India          265        7.8
# 85853              Drama, Family            Turkey          194        9.4
# 85854                      Drama             Spain          102        6.8
#
# [85855 rows x 7 columns]

# %% [markdown]
# ### 1.2 Outer join (Full join)

# %%
df_outer_join = df1.merge(df2, on='id', how='outer')
df_outer_join
# Out:
#   id   age           job
# 0  A  30.0           NaN
# 1  B  23.0           NaN
# 2  C  25.0        Doctor
# 3  D  22.0  Statistician
# 4  E   NaN    Accountant
# 5  F   NaN     Developer

# %%
# shape

print(df1.shape)
print(df2.shape)
print(df_inner_join.shape)
print(df_outer_join.shape)
# Out:
# (4, 2)
# (4, 2)
# (2, 3)
# (6, 3)

# %% [markdown]
# ### 1.2.1 Exercise

# %%
# merge df_movies and df_ratings (outer join)

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='outer')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# 2                          Drama  Germany, Denmark          188        6.0
# 3                 Drama, History               USA          446        5.3
# 4      Adventure, Drama, Fantasy             Italy         2237        6.9
# ...                          ...               ...          ...        ...
# 85850                     Comedy   France, Belgium          398        5.5
# 85851              Comedy, Drama       Netherlands          724        7.9
# 85852                      Drama             India          265        7.8
# 85853              Drama, Family            Turkey          194        9.4
# 85854                      Drama             Spain          102        6.8
#
# [85855 rows x 7 columns]

# %% [markdown]
# ### 1.3 Exclusive Outer join (Exclusive full join)

# %%
df1.merge(df2, on='id', how='outer', indicator=True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
# query

df_exclusive_outer_join = df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='left_only' or _merge=='right_only'")
df_exclusive_outer_join
# Out:
#   id   age         job      _merge
# 0  A  30.0         NaN   left_only
# 1  B  23.0         NaN   left_only
# 4  E   NaN  Accountant  right_only
# 5  F   NaN   Developer  right_only

# %%
# shape
print(df_exclusive_outer_join.shape)
# Out:
# (4, 4)

# %% [markdown]
# ### 1.3.1 Exercise

# %%
# merge df_movies and df_ratings

df_movies.merge(df_ratings, on='imdb_title_id', how='outer', indicator=True)
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote  \
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# 2                          Drama  Germany, Denmark          188        6.0
# 3                 Drama, History               USA          446        5.3
# 4      Adventure, Drama, Fantasy             Italy         2237        6.9
# ...                          ...               ...          ...        ...
# 85850                     Comedy   France, Belgium          398        5.5
# 85851              Comedy, Drama       Netherlands          724        7.9
# 85852                      Drama             India          265        7.8
# 85853              Drama, Family            Turkey          194        9.4
# 85854                      Drama             Spain          102        6.8
#
#       _merge
# 0       both
# 1       both
# 2       both
# 3       both
# 4       both
# ...      ...
# 85850   both
# 85851   both
# 85852   both
# 85853   both
# 85854   both
#
# [85855 rows x 8 columns]

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='outer', indicator=True).query("_merge=='left_only' or _merge=='right_only'")
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, year, genre, country, total_votes, mean_vote, _merge]
# Index: []

# %% [markdown]
# ### 1.4 Left join

# %%
df1.merge(df2, on='id', how='left')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician

# %% [markdown]
# ### 1.4.1 Exercise

# %%
# extract a 50% sample of the df_movies dataframe

df_movies_sample = df_movies.sample(frac=0.5)
df_movies_sample
# Out:
#       imdb_title_id                        title  year  \
# 58231     tt1448755                 Killer Elite  2011
# 44153     tt0377051                  Dimmi di sì  2004
# 9313      tt0050993            Qualcosa che vale  1957
# 48099     tt0468864         Shinkokyû no hitsuyô  2004
# 30130     tt0117600                       Septej  1996
# ...             ...                          ...   ...
# 52192     tt0996982                      Turneja  2008
# 69002     tt2901062           Puthiya Theerangal  2012
# 83190     tt7767336  Varikkuzhiyile Kolapathakam  2019
# 76602     tt5060166             Beyond the Woods  2018
# 27505     tt0107621          Un muro de silencio  1993
#
#                            genre  \
# 58231           Action, Thriller
# 44153                     Comedy
# 9313                  Drama, War
# 48099                      Drama
# 30130                    Romance
# ...                          ...
# 52192  Action, Adventure, Comedy
# 69002              Comedy, Drama
# 83190  Comedy, Mystery, Thriller
# 76602     Drama, Horror, Mystery
# 27505                      Drama
#
#                                                  country
# 58231                                      UK, Australia
# 44153                                              Spain
# 9313                                                 USA
# 48099                                              Japan
# 30130                                     Czech Republic
# ...                                                  ...
# 52192  Serbia, Bosnia and Herzegovina, Croatia, Slovenia
# 69002                                              India
# 83190                                              India
# 76602                                            Ireland
# 27505                              Argentina, Mexico, UK
#
# [42928 rows x 5 columns]

# %%
# merge df_movies_sample and df_ratings (left join)

df_left = df_movies_sample.merge(df_ratings, on='imdb_title_id', how='left')
df_left
# Out:
#       imdb_title_id                        title  year  \
# 0         tt1448755                 Killer Elite  2011
# 1         tt0377051                  Dimmi di sì  2004
# 2         tt0050993            Qualcosa che vale  1957
# 3         tt0468864         Shinkokyû no hitsuyô  2004
# 4         tt0117600                       Septej  1996
# ...             ...                          ...   ...
# 42923     tt0996982                      Turneja  2008
# 42924     tt2901062           Puthiya Theerangal  2012
# 42925     tt7767336  Varikkuzhiyile Kolapathakam  2019
# 42926     tt5060166             Beyond the Woods  2018
# 42927     tt0107621          Un muro de silencio  1993
#
#                            genre  \
# 0               Action, Thriller
# 1                         Comedy
# 2                     Drama, War
# 3                          Drama
# 4                        Romance
# ...                          ...
# 42923  Action, Adventure, Comedy
# 42924              Comedy, Drama
# 42925  Comedy, Mystery, Thriller
# 42926     Drama, Horror, Mystery
# 42927                      Drama
#
#                                                  country  total_votes  \
# 0                                          UK, Australia       122289
# 1                                                  Spain          719
# 2                                                    USA          940
# 3                                                  Japan          222
# 4                                         Czech Republic          264
# ...                                                  ...          ...
# 42923  Serbia, Bosnia and Herzegovina, Croatia, Slovenia         2467
# 42924                                              India          126
# 42925                                              India          422
# 42926                                            Ireland         3052
# 42927                              Argentina, Mexico, UK          154
#
#        mean_vote
# 0            6.6
# 1            5.4
# 2            6.7
# 3            6.7
# 4            6.9
# ...          ...
# 42923        7.3
# 42924        4.9
# 42925        6.8
# 42926        7.3
# 42927        7.1
#
# [42928 rows x 7 columns]

# %%
# shape

print(df_movies_sample.shape)
print(df_ratings.shape)
print(df_left.shape)
# Out:
# (42928, 5)
# (85855, 3)
# (42928, 7)

# %% [markdown]
# ### 1.5 Exclusive Left join

# %%
df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='left_only'")
# Out:
#   id   age  job     _merge
# 0  A  30.0  NaN  left_only
# 1  B  23.0  NaN  left_only

# %% [markdown]
# ### 1.5.1 Exercise

# %%
# make a copy of the df_movies dataframe 

df_movies_2 = df_movies.copy()

df_movies_2
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
# [85855 rows x 5 columns]

# %%
# set the first 1000 values of 'imdb_title_id' column as tt1234567890

df_movies_2.loc[:999, 'imdb_title_id'] = 'tt1234567890'
df_movies_2
# Out:
#       imdb_title_id                           title  year  \
# 0      tt1234567890                      Miss Jerry  1894
# 1      tt1234567890     The Story of the Kelly Gang  1906
# 2      tt1234567890                  Den sorte drøm  1911
# 3      tt1234567890                       Cleopatra  1912
# 4      tt1234567890                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
# [85855 rows x 5 columns]

# %%
# merge df_movies_2 and df_ratings (exclusive left join)

df_exclusive_left = df_movies_2.merge(df_ratings, on='imdb_title_id', how='outer', indicator=True).query("_merge=='left_only'")
df_exclusive_left
# Out:
#       imdb_title_id                        title  year  \
# 55817  tt1234567890                   Miss Jerry  1894
# 55818  tt1234567890  The Story of the Kelly Gang  1906
# 55819  tt1234567890               Den sorte drøm  1911
# 55820  tt1234567890                    Cleopatra  1912
# 55821  tt1234567890                    L'Inferno  1911
# ...             ...                          ...   ...
# 56812  tt1234567890            Agente segreto Z1  1930
# 56813  tt1234567890                   Tom Sawyer  1930
# 56814  tt1234567890               Tonka Sibenice  1930
# 56815  tt1234567890                    Top Speed  1930
# 56816  tt1234567890             True to the Navy  1930
#
#                            genre                  country  total_votes  \
# 55817                    Romance                      USA          NaN
# 55818    Biography, Crime, Drama                Australia          NaN
# 55819                      Drama         Germany, Denmark          NaN
# 55820             Drama, History                      USA          NaN
# 55821  Adventure, Drama, Fantasy                    Italy          NaN
# ...                          ...                      ...          ...
# 56812                      Drama                      USA          NaN
# 56813   Adventure, Comedy, Drama                      USA          NaN
# 56814                      Drama  Czechoslovakia, Germany          NaN
# 56815   Comedy, Musical, Romance                      USA          NaN
# 56816    Action, Comedy, Romance                      USA          NaN
#
#        mean_vote     _merge
# 55817        NaN  left_only
# 55818        NaN  left_only
# 55819        NaN  left_only
# 55820        NaN  left_only
# 55821        NaN  left_only
# ...          ...        ...
# 56812        NaN  left_only
# 56813        NaN  left_only
# 56814        NaN  left_only
# 56815        NaN  left_only
# 56816        NaN  left_only
#
# [1000 rows x 8 columns]

# %%
# shape

print(df_exclusive_left.shape)
print(df_movies_2.shape)
print(df_ratings.shape)
# Out:
# (1000, 8)
# (85855, 5)
# (85855, 3)

# %% [markdown]
# ### 1. Right Join

# %%
df1.merge(df2, on='id', how='right')
# Out:
#   id   age           job
# 0  C  25.0        Doctor
# 1  D  22.0  Statistician
# 2  E   NaN    Accountant
# 3  F   NaN     Developer

# %% [markdown]
# ### 1.6.1 Exercise

# %%
# extract a 30% sampleof the df_ratings dataframe

df_ratings_sample = df_ratings.sample(frac=0.3)

# %%
# merge df_movies and df_ratings_sample (right join)

df_right = df_movies.merge(df_ratings_sample, on='imdb_title_id', how='right')
df_right
# Out:
#       imdb_title_id                                           title  year  \
# 0         tt1169133                                         Anytown  2009
# 1         tt0049846                              Fascino e perfidia  1956
# 2         tt5578604                                           Vikes  2017
# 3         tt0063057                     I contrabbandieri del cielo  1968
# 4         tt0875609            Pokémon: Lucario e il mistero di Mew  2005
# ...             ...                                             ...   ...
# 25751     tt2672180                                  Silent Retreat  2013
# 25752     tt0377923                               Luen ji fung ging  2003
# 25753     tt0088116                                  Silent Madness  1984
# 25754     tt0122544  Einai enas... trellos, trellos, trellos Vengos  1965
# 25755     tt5703038                                     Monsterland  2016
#
#                               genre            country  total_votes  mean_vote
# 0            Crime, Drama, Thriller                USA          327        5.4
# 1           Crime, Drama, Film-Noir                USA          156        5.9
# 2                   Comedy, Romance                USA          102        5.7
# 3                             Drama                USA          194        6.3
# 4      Animation, Action, Adventure              Japan         3903        7.3
# ...                             ...                ...          ...        ...
# 25751     Horror, Mystery, Thriller             Canada          709        4.5
# 25752     Animation, Drama, Romance  Hong Kong, France          208        6.5
# 25753              Horror, Thriller                USA          575        5.3
# 25754                        Comedy             Greece          314        7.2
# 25755       Comedy, Fantasy, Horror                USA          332        5.8
#
# [25756 rows x 7 columns]

# %%
# shape

print(df_ratings_sample.shape)
print(df_movies.shape)
print(df_right.shape)
# Out:
# (25756, 3)
# (85855, 5)
# (25756, 7)

# %% [markdown]
# ### 1.7 Exclusive right join

# %%
# indicator = True

df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='right_only'")
# Out:
#   id  age         job      _merge
# 4  E  NaN  Accountant  right_only
# 5  F  NaN   Developer  right_only

# %% [markdown]
# ### 1.7.1 Exercise

# %%
# make a copy of the df_ratings dataframe

df_ratings_copy = df_ratings.copy()

# %%
# set the first 1000 values of 'imdb_title_id' column as tt1234567890

df_ratings_copy.loc[:999, 'imdb_title_id'] = 'tt1234567890'
df_ratings_copy
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0      tt1234567890          154        5.9
# 1      tt1234567890          589        6.3
# 2      tt1234567890          188        6.0
# 3      tt1234567890          446        5.3
# 4      tt1234567890         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %%
# merge df_movies and df_ratings_2 (exclusive right join)

df_exclusive_right_join = df_movies.merge(df_ratings_copy, on='imdb_title_id', how='outer', indicator=True).query("_merge=='right_only'")
df_exclusive_right_join
# Out:
#       imdb_title_id title year genre country  total_votes  mean_vote  \
# 55817  tt1234567890   NaN  NaN   NaN     NaN        154.0        5.9
# 55818  tt1234567890   NaN  NaN   NaN     NaN        589.0        6.3
# 55819  tt1234567890   NaN  NaN   NaN     NaN        188.0        6.0
# 55820  tt1234567890   NaN  NaN   NaN     NaN        446.0        5.3
# 55821  tt1234567890   NaN  NaN   NaN     NaN       2237.0        6.9
# ...             ...   ...  ...   ...     ...          ...        ...
# 56812  tt1234567890   NaN  NaN   NaN     NaN        128.0        5.8
# 56813  tt1234567890   NaN  NaN   NaN     NaN        160.0        6.6
# 56814  tt1234567890   NaN  NaN   NaN     NaN        106.0        7.2
# 56815  tt1234567890   NaN  NaN   NaN     NaN        172.0        6.2
# 56816  tt1234567890   NaN  NaN   NaN     NaN        103.0        7.0
#
#            _merge
# 55817  right_only
# 55818  right_only
# 55819  right_only
# 55820  right_only
# 55821  right_only
# ...           ...
# 56812  right_only
# 56813  right_only
# 56814  right_only
# 56815  right_only
# 56816  right_only
#
# [1000 rows x 8 columns]

# %%
# shape

print(df_exclusive_right_join.shape)
print(df_ratings_copy.shape)
print(df_movies.shape)
# Out:
# (1000, 8)
# (85855, 3)
# (85855, 5)
