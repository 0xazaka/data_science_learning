# %%
print("Hi, My name is Azaka")
# Out:
# Hi, My name is Azaka

# %%
message1 = "I'm learning python" 
message2 = "and its fun"
message = message1 + " " + message2
print(message)
# Out:
# I'm learning python and its fun

# %%
f'{message1} {message2}'
# Out:
# "I'm learning python and its fun"
