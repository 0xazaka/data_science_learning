# %%
def sum(a,b):
    x = a + b
    return x

# %%
x = int(input('first number: '))
y = int(input('second number: '))
sum(x,y)
# Out:
# 9

# %% [markdown]
# # Built in functions

# %%
countries = ['United States', 'India', 'China', 'Brazil']
len(countries)
# Out:
# 4

# %%
max([6,7,8,2,90,101,67,69])
# Out:
# 101

# %%
min([6,7,8,2,90,101,67,69])
# Out:
# 2

# %%
type(countries)
# Out:
# list

# %%
for i in range(1,20,3):
    print(i)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
