# %%
import os

# %% [markdown]
# ### OS Module

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Windows\\Desktop\\PY'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '3_variables.ipynb',
#  '4_lists.ipynb',
#  '5_dictionaries.ipynb',
#  '6_if_statements.ipynb',
#  '7_for_loops.ipynb',
#  '8_functions.ipynb',
#  '9_modules.ipynb',
#  'udemy py.ipynb']
