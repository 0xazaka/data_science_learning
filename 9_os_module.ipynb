# %%
import os

# %% [markdown]
# ### OS Module

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Windows\\Desktop\\PY\\data_science_learning'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '10_dataframe.ipynb',
#  '11_attributes,methods,functions.ipynb',
#  '12_selecting_columns_from_a_DF.ipynb',
#  '13_adding_new_columns_to_a_df.ipynb',
#  '14_operations_on_DataFrames.ipynb',
#  '15_the_value_counts()_method.ipynb',
#  '16_sort_a_DF_with_sort_values().ipynb',
#  '17_set_index()_and_sort_index().ipynb',
#  '3_variables.ipynb',
#  '4_lists.ipynb',
#  '5_dictionaries.ipynb',
#  '6_if_statements.ipynb',
#  '7_for_loops.ipynb',
#  '8_functions.ipynb',
#  '9_os_module.ipynb',
#  'StudentsPerformance.csv']
