# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_data = {'name': 'Azaka', 'age': 21}
my_data
# Out:
# {'name': 'Azaka', 'age': 21}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Azaka', 21])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Azaka'), ('age', 21)])

# %%
my_data['height'] = 1.81
my_data
# Out:
# {'name': 'Azaka', 'age': 21, 'height': 1.81}

# %%
my_data.update({'height': 1.80})
my_data
# Out:
# {'name': 'Azaka', 'age': 21, 'height': 1.8}

# %%
new_dict = my_data.copy()

# %%
print(new_dict)
# Out:
# {'name': 'Azaka', 'age': 21, 'height': 1.8}

# %%
new_dict2 = my_data
new_dict2
# Out:
# {'name': 'Azaka', 'age': 21, 'height': 1.8}
