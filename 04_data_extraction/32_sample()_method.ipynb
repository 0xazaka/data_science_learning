# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv('players_20.csv')

# set index
df.set_index('short_name', inplace=True)

# select necessary columns
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall']]

# show dataframe
df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid
#
#                    overall
# short_name
# ...

# %% [markdown]
# ### 1. sample()

# %%
# extract 10 random elements from the 'nationality' column

df['nationality'].sample(10, random_state=1)
# Out:
# short_name
# D. Cvetinović            Serbia
# M. Silva                Uruguay
# S. Mandash         Saudi Arabia
# I. Gruev               Bulgaria
# Kangin Lee       Korea Republic
# Marc Cardona              Spain
# R. Nteka                 France
# J. Mikel                Nigeria
# He Chao                China PR
# P. Ruffaut               France
# Name: nationality, dtype: object

# %%
# extract a random 20% sample of the dataframe

df.sample(frac=0.2, random_state=12)
# Out:
#                                long_name  age         dob  height_cm  \
# short_name
# Y. Thoelen               Yannick Thoelen   28  1990-07-18        188
# M. Nadé                     Mickaël Nadé   20  1999-03-04        188
# V. García   Víctor Hugo García Hernández   25  1994-06-11        178
# M. Gyamfi                 Maxwell Gyamfi   19  2000-01-18        185
# W. Cyprien                 Wylan Cyprien   24  1995-01-28        180
# ...                                  ...  ...         ...        ...
# H. Kadish                  Hassan Kadish   26  1992-09-26        179
# A. Chapman                 Aaron Chapman   29  1990-05-29        203
# I. Ezekiel                  Imoh Ezekiel   25  1993-10-24        178
# H. Sakai                           酒井 宏樹   29  1990-04-12        183
# C. Keșerü          Claudiu Andrei Keșerü   32  1986-12-02        178
#
#             weight_kg   nationality                    club  overall
# short_name
# ...

# %%
# upsample: increase the sampling rate -> frac>1 (Note: replace parameter has to be True for frac parameter > 1)

df.sample(frac=2, replace=True, random_state=99)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# M. Hauptmeijer               Mike Hauptmeijer   22  1997-03-18        191
# A. Mosquera                   Andrés Mosquera   29  1990-02-20        182
# V. Thill                        Vincent Thill   19  2000-02-04        172
# D. Bouanga                      Denis Bouanga   24  1994-11-11        180
# S. Al Selouli                 Saad Al Selouli   21  1998-05-25        168
# ...                                       ...  ...         ...        ...
# M. Connor                      Matthew Connor   22  1997-04-08        192
# J. Northcott                 Jordan Northcott   17  2002-02-09        162
# A. Bodzek                         Adam Bodzek   33  1985-09-07        184
# J. Adebayo-Smith         Jordan Adebayo-Smith   18  2001-01-11        181
# F. Mac Allister   Francis Manuel Mac Allister   23  1995-10-30        176
#
# ...
