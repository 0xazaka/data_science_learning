# %%
import pandas as pd

# %%
df = pd.read_csv('players_20.csv')
df.set_index('short_name', inplace=True)
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall']]
df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid
#
#                    overall
# short_name
# L. Messi                94
# Cristiano Ronaldo       93
# Neymar Jr               92
# J. Oblak                91
# E. Hazard               91

# %% [markdown]
# ### 1. Set value to one cell

# %%
# update L. Messi height

df.loc['L. Messi', 'height_cm'] = 175
df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi                 175         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid
#
#                    overall
# short_name
# L. Messi                94
# Cristiano Ronaldo       93
# Neymar Jr               92
# J. Oblak                91
# E. Hazard               91

# %% [markdown]
# ### 2. Set value to an entire column

# %%
# set height of all players to 190

df.loc[:, 'height_cm'] = 190
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 190         72   Argentina
# Cristiano Ronaldo        190         83    Portugal
# Neymar Jr                190         68      Brazil
# J. Oblak                 190         87    Slovenia
# E. Hazard                190         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               190         79    China PR
# Xiao Mingjie             190         66    China PR
# Zhang Wei                190         75    China PR
# Wang Haijian             190         74    China PR
# Pan Ximing               190         78    China PR
#
#                                             club  overall
# short_name
# L. Messi                            FC Barcelona       94
# Cristiano Ronaldo                       Juventus       93
# Neymar Jr                    Paris Saint-Germain       92
# J. Oblak                         Atlético Madrid       91
# E. Hazard                            Real Madrid       91
# ...                                          ...      ...
# Shao Shuai                      Beijing Renhe FC       48
# Xiao Mingjie                    Shanghai SIPG FC       48
# Zhang Wei                 Hebei China Fortune FC       48
# Wang Haijian       Shanghai Greenland Shenhua FC       48
# Pan Ximing                Hebei China Fortune FC       48
#
# [18278 rows x 8 columns]

# %% [markdown]
# ### 3. Set value to entire row

# %%
# get all the columns that correspond to player ranked last in FIFA

df.loc['Pan Ximing', :]

# or

df.iloc[-1, :]
# Out:
# long_name                         潘喜明
# age                                26
# dob                        1993-01-11
# height_cm                         190
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# overall                            48
# Name: Pan Ximing, dtype: object

# %%
# set null values to all columns that corresponds to player ranked last

import numpy as np
np.nan

df.iloc[-1, :] = np.nan

# %%
# show dataframe

df.tail(5)
# Out:
#                  long_name   age         dob  height_cm  weight_kg  \
# short_name
# Shao Shuai              邵帅  22.0  1997-03-10      190.0       79.0
# Xiao Mingjie  Mingjie Xiao  22.0  1997-01-01      190.0       66.0
# Zhang Wei               张威  19.0  2000-05-16      190.0       75.0
# Wang Haijian           汪海健  18.0  2000-08-02      190.0       74.0
# Pan Ximing             NaN   NaN         NaN        NaN        NaN
#
#              nationality                           club  overall
# short_name
# Shao Shuai      China PR               Beijing Renhe FC     48.0
# Xiao Mingjie    China PR               Shanghai SIPG FC     48.0
# Zhang Wei       China PR         Hebei China Fortune FC     48.0
# Wang Haijian    China PR  Shanghai Greenland Shenhua FC     48.0
# Pan Ximing           NaN                            NaN      NaN

# %% [markdown]
# ### 4. Set value to multiple cells

# %%
# Set value for all items matching the list of labels

df.loc[['L. Messi', 'Cristiano Ronaldo'], ['height_cm']] = 175

# %%
# show dataframe
df.head()
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi               175.0       72.0   Argentina         FC Barcelona
# Cristiano Ronaldo      175.0       83.0    Portugal             Juventus
# Neymar Jr              190.0       68.0      Brazil  Paris Saint-Germain
# J. Oblak               190.0       87.0    Slovenia      Atlético Madrid
# E. Hazard              190.0       74.0     Belgium          Real Madrid
#
#                    overall
# short_name
# L. Messi              94.0
# Cristiano Ronaldo     93.0
# Neymar Jr             92.0
# J. Oblak              91.0
# E. Hazard             91.0

# %% [markdown]
# ### 5. Set value for rows matching a condition

# %%
# set value for rows matching a condition
columns = ['age', 'dob', 'height_cm', 'weight_kg']

# for this example, we want to set a value for rows of players having a height above 180cm

df.loc[df['height_cm'] > 180, columns]
# Out:
#                 age         dob  height_cm  weight_kg
# short_name
# Neymar Jr      27.0  1992-02-05      190.0       68.0
# J. Oblak       26.0  1993-01-07      190.0       87.0
# E. Hazard      28.0  1991-01-07      190.0       74.0
# K. De Bruyne   28.0  1991-06-28      190.0       70.0
# M. ter Stegen  27.0  1992-04-30      190.0       85.0
# ...             ...         ...        ...        ...
# P. Martin      20.0  1999-01-05      190.0       84.0
# Shao Shuai     22.0  1997-03-10      190.0       79.0
# Xiao Mingjie   22.0  1997-01-01      190.0       66.0
# Zhang Wei      19.0  2000-05-16      190.0       75.0
# Wang Haijian   18.0  2000-08-02      190.0       74.0
#
# [18275 rows x 4 columns]
